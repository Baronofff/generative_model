# %%
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# !pip install nltk --upgrade
# !pip install wordcloud
# Out:
# Requirement already satisfied: pandas in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (from pandas) (2.2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: matplotlib in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (from matplotlib) (2.2.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: seaborn in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (from seaborn) (2.2.5)
# Requirement already satisfied: pandas>=1.2 in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (from seaborn) (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Requirement already satisfied: nltk in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (from click->nltk) (0.4.6)
# Requirement already satisfied: wordcloud in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (from wordcloud) (2.2.5)
# Requirement already satisfied: pillow in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (from wordcloud) (11.2.1)
# Requirement already satisfied: matplotlib in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (from wordcloud) (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (from matplotlib->wordcloud) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (from matplotlib->wordcloud) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (from matplotlib->wordcloud) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (from matplotlib->wordcloud) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\user\programming_projects\generative_model\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import re
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from wordcloud import WordCloud

nltk.download('punkt_tab')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
with open('collect.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# %%
from pathlib import Path

file = Path('collect.txt')
size_gb = file.stat().st_size / (1024 ** 3)
print(f"Размер файла: {size_gb:.3f} GB")
# Out:
# Размер файла: 0.987 GB

# %%
def count_words(filepath):
    with open(filepath, 'r', encoding='utf-8') as f:
        text = f.read()
        words = text.split()  # Разбиение по whitespace
        return len(words)

def count_sentences_simple(filepath):
    with open(filepath, 'r', encoding='utf-8') as f:
        text = f.read()
        sentences = [s.strip() for s in re.split(r'[.!?…]+', text) if s.strip()]
        return len(sentences)
    
def avg_sentence_length_basic(filepath):
    with open(filepath, 'r', encoding='utf-8') as f:
        text = f.read()

        sentences = [s.strip() for s in re.split(r'[.!?…]+', text) if s.strip()]
        
        word_counts = [len(re.findall(r'\w+', s)) for s in sentences]
        
        return sum(word_counts) / len(word_counts) if word_counts else 0

# %%
print("=== Основные метрики текста ===")
print(f"Общее количество символов: {len(text)}")
print(f"Количество слов: {count_words('collect.txt')}")
print(f"Количество предложений: {count_sentences_simple('collect.txt')}")
print(f"Средняя длина предложения: {avg_sentence_length_basic('collect.txt'):.1f} слов")
# Out:
# === Основные метрики текста ===
# Общее количество символов: 591689447
# Количество слов: 86174448
# Количество предложений: 7046319
# Средняя длина предложения: 12.2 слов

# %%
print("=== Основные метрики текста ===")
print(f"Общее количество символов: {len(text)}")
print(f"Общее количество слов: {len(word_tokenize(text))}")
print(f"Общее количество предложений: {len(sent_tokenize(text))}")
print(f"Средняя длина предложения (в словах): {round(len(word_tokenize(text)) / len(sent_tokenize(text)), 2)}")
# Out:
# === Основные метрики текста ===
# Общее количество символов: 591689447
# Общее количество слов: 107757720
# Общее количество предложений: 5787557
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 5
#       3 print(f"Общее количество слов: {len(word_tokenize(text))}")
#       4 print(f"Общее количество предложений: {len(sent_tokenize(text))}")
# ----> 5 print(f"Средняя длина предложения (в словах): {round(len(word_tokenize(text)) / len(sent_tokenize(text)), 2)}")
#
# File c:\Users\user\programming_projects\generative_model\venv\Lib\site-packages\nltk\tokenize\__init__.py:120, in sent_tokenize(text, language)
#     110 """
#     111 Return a sentence-tokenized copy of *text*,
#     112 using NLTK's recommended sentence tokenizer
#    (...)    117 :param language: the model name in the Punkt corpus
#     118 """
#     119 tokenizer = _get_punkt_tokenizer(language)
# --> 120 return tokenizer.tokenize(text)
#
# File c:\Users\user\programming_projects\generative_model\venv\Lib\site-packages\nltk\tokenize\punkt.py:1280, in PunktSentenceTokenizer.tokenize(self, text, realign_boundaries)
#    1276 def tokenize(self, text: str, realign_boundaries: bool = True) -> List[str]:
#    1277     """
#    1278     Given a text, returns a list of the sentences in that text.
#    1279     """
# -> 1280     return list(self.sentences_from_text(text, realign_boundaries))
#
# File c:\Users\user\programming_projects\generative_model\venv\Lib\site-packages\nltk\tokenize\punkt.py:1340, in PunktSentenceTokenizer.sentences_from_text(self, text, realign_boundaries)
#    1331 def sentences_from_text(
#    1332     self, text: str, realign_boundaries: bool = True
#    1333 ) -> List[str]:
#    1334     """
#    1335     Given a text, generates the sentences in that text by only
#    1336     testing candidate sentence breaks. If realign_boundaries is
#    1337     True, includes in the sentence closing punctuation that
#    1338     follows the period.
#    1339     """
# -> 1340     return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#
# File c:\Users\user\programming_projects\generative_model\venv\Lib\site-packages\nltk\tokenize\punkt.py:1340, in <listcomp>(.0)
#    1331 def sentences_from_text(
#    1332     self, text: str, realign_boundaries: bool = True
#    1333 ) -> List[str]:
#    1334     """
#    1335     Given a text, generates the sentences in that text by only
#    1336     testing candidate sentence breaks. If realign_boundaries is
#    1337     True, includes in the sentence closing punctuation that
#    1338     follows the period.
#    1339     """
# -> 1340     return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#
# KeyboardInterrupt:

# %%
words = word_tokenize(text.lower())
words = [word for word in words if word.isalpha()]  # Убираем цифры и спецсимволы
stop_words = set(stopwords.words('russian'))  # Для английского: 'english'
filtered_words = [word for word in words if word not in stop_words]

word_freq = Counter(filtered_words).most_common(20)
print("\n=== Топ-20 самых частых слов (без стоп-слов) ===")
for word, freq in word_freq:
    print(f"{word}: {freq}")
# Out:
# === Топ-20 самых частых слов (без стоп-слов) ===
# въ: 962988
# съ: 372695
# это: 362170
# онъ: 270472
# какъ: 230488
# къ: 213539
# изъ: 150030
# отъ: 133819
# время: 121654
# такъ: 117251
# очень: 102430
# мнѣ: 85035
# ихъ: 84692
# который: 82480
# своей: 81857
# жизни: 80640
# былъ: 78906
# которые: 74753
# ея: 66507
# своего: 65444

# %% [markdown]
# lemmatization?

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=[freq for word, freq in word_freq], y=[word for word, freq in word_freq])
plt.title("Топ-20 самых частых слов")
plt.xlabel("Частота")
plt.ylabel("Слово")
plt.show()

# %%
words = word_tokenize(text.lower())
words = [word for word in words if word.isalpha()]  # Убираем цифры и спецсимволы
stop_words = set(stopwords.words('russian'))  # Для английского: 'english'
filtered_words = [word for word in words if word not in stop_words]
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join(filtered_words))
plt.figure(figsize=(12, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title("Облако слов (без стоп-слов)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[7], line 5
#       3 stop_words = set(stopwords.words('russian'))  # Для английского: 'english'
#       4 filtered_words = [word for word in words if word not in stop_words]
# ----> 5 wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join(filtered_words))
#       6 plt.figure(figsize=(12, 8))
#       7 plt.imshow(wordcloud, interpolation='bilinear')
#
# File c:\Users\user\programming_projects\generative_model\venv\Lib\site-packages\wordcloud\wordcloud.py:642, in WordCloud.generate(self, text)
#     627 def generate(self, text):
#     628     """Generate wordcloud from text.
#     629
#     630     The input "text" is expected to be a natural text. If you pass a sorted
#    (...)    640     self
#     641     """
# --> 642     return self.generate_from_text(text)
#
# File c:\Users\user\programming_projects\generative_model\venv\Lib\site-packages\wordcloud\wordcloud.py:623, in WordCloud.generate_from_text(self, text)
#     606 def generate_from_text(self, text):
#     607     """Generate wordcloud from text.
#     608
#     609     The input "text" is expected to be a natural text. If you pass a sorted
#    (...)    621     self
#     622     """
# --> 623     words = self.process_text(text)
#     624     self.generate_from_frequencies(words)
#     625     return self
#
# File c:\Users\user\programming_projects\generative_model\venv\Lib\site-packages\wordcloud\wordcloud.py:587, in WordCloud.process_text(self, text)
#     585 words = re.findall(regexp, text, flags)
#     586 # remove 's
# --> 587 words = [word[:-2] if word.lower().endswith("'s") else word
#     588          for word in words]
#     589 # remove numbers
#     590 if not self.include_numbers:
#
# File c:\Users\user\programming_projects\generative_model\venv\Lib\site-packages\wordcloud\wordcloud.py:587, in <listcomp>(.0)
#     585 words = re.findall(regexp, text, flags)
#     586 # remove 's
# --> 587 words = [word[:-2] if word.lower().endswith("'s") else word
#     588          for word in words]
#     589 # remove numbers
#     590 if not self.include_numbers:
#
# MemoryError:

# %%
sentences = sent_tokenize(text)
sentence_lengths = [len(word_tokenize(sent)) for sent in sentences]

plt.figure(figsize=(10, 6))
sns.histplot(sentence_lengths, bins=30, kde=True)
plt.title("Распределение длины предложений (в словах)")
plt.xlabel("Длина предложения")
plt.ylabel("Количество")
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
words = word_tokenize(text.lower())

# %%
unique_words = set(words)
print(f"\nКоличество уникальных слов: {len(unique_words)}")
print(f"Лексическое разнообразие (уникальные слова / общее количество слов): {round(len(unique_words) / len(words), 3)}")
# Out:
# Количество уникальных слов: 1718193
# Лексическое разнообразие (уникальные слова / общее количество слов): 0.016

# %% [markdown]
# лексическое разнообразие - плохо(не прям совсем)

# %%
rare_words = [word for word, count in Counter(words).items() if count <= 2]
print(f"\nКоличество редких слов (встречаются ≤ 2 раз): {len(rare_words)}")
print("Примеры редких слов:", rare_words[:10])
# Out:
# Количество редких слов (встречаются ≤ 2 раз): 1060053
# Примеры редких слов: ['казаки.донцы', 'колокольная', '14.1890.', 'оглавлене', 'кагь', 'иканомъ', 'черноморсхая', 'сдашісь', 'гребенское', 'каказская']

# %%
html_tags = re.findall(r'<.*?>', text)
if html_tags:
    print(f"\nВнимание: найдены HTML-теги ({len(html_tags)} шт.)")
else:
    print("\nHTML-теги не обнаружены.")
# Out:
# HTML-теги не обнаружены.

# %% [markdown]
# 1. Объём данных (0.987 GB)
# Вывод: Корпус значительного размера (~1 GB), что достаточно для обучения моделей NLP.
#
# 2. Лексические характеристики
# Общее количество слов: 107.7 млн
# Уникальных слов: 1.7 млн
#
# Лексическое разнообразие (0.016):
#
# Низкий показатель (норма для художественных текстов: 0.1–0.3).
# Причина: Частые повторы слов (например, въ, съ, это встречаются сотни тысяч раз, можно посмотреть лексическое разнообразие без этих слов, однако стоит учитывать пропорции в современном языке и в 19в(в 19 веке служебные слова использовались чаще чем сейчас)).
#
#
# Редкие слова: 1.06 млн (62% уникальной лексики).
# Примеры: 'оглавлене', 'иканомъ', 'черноморсхая'.
#
# Проблема: Старорусские слова имеют различное написание в зависимости от диалекта.
#
# Решение:
#
# не нужно, так как модель будет отображать языковой портрет всей эпохи, а не конкретного диалекта
#
#
# 3. Структура текста
# Средняя длина предложения:
# 18.6 слов.
#
# Вывод: Предложения сложные, характерные для классической литературы, романов.
#
# 4. Топ-20 частых слов
# Особенности:
#
# Доминируют архаичные формы (въ, съ, онъ).
#
# Высокая частотность предлогов/местоимений (къ, отъ, который).
#
# Интерпретация:
# Тексты содержат много служебных слов, что типично для русской литературы 19 в.
#
# 5. Отсутствие HTML-тегов
# Вывод: Данные уже очищены от разметки при парсинге, что упрощает обработку.
